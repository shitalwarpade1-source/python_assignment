# %% [markdown]
# <a href="https://colab.research.google.com/github/shitalwarpade1-source/test/blob/main/linkcodecw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.	Write a Python program to take two numbers as input from the user and display their sum.

# %%
name1 = int(input("Enter a Number "))
name2 = int(input("Enter a number"))
sum = name1 + name2
print(sum)
# Out:
# Enter a Number 6
# Enter a number7
# 13

# %% [markdown]
# 2.	Calculate and print the midpoint of two numbers entered by the user.

# %%
num1 = float(input("Enter a number"))
num2 = float(input("Enter a number"))
midpoint = (num1 + num2) / 2
print(midpoint)
# Out:
# Enter a number6
# Enter a number7
# 6.5

# %% [markdown]
# 3.	Write a Python program to calculate the area of a triangle using the formula: area = 0.5 * base * height.

# %%
base = float(input("enter the base of tringle"))
height = float(input("enter the height of tringle"))
area_tringle = 0.5* base * height
print(area_tringle)
# Out:
# enter the base of tringle7
# enter the height of tringle9
# 31.5

# %% [markdown]
# 4.	Take three numbers as input from the user and display their product.

# %%
num1 = int(input("enter a first number"))
num2 = int(input("enter a second number"))
num3 = int(input("enter a three number"))
product = num1 * num2 * num3
print(product)
# Out:
# enter a first number4
# enter a second number6
# enter a three number9
# 216

# %% [markdown]
# 5.	Take a number as input and display its square and cube.

# %%
num = int(input("enter a number:"))
squre = num ** 2
cube = num ** 3
print(squre)
print(cube)
# Out:
# enter a number:6
# 36
# 216

# %% [markdown]
# 6.	Take two numbers as input and display their quotient and remainder.

# %%
num1 = float(input("the dividend (number to divide): "))
num2 = float(input("Enter the divisor: "))
quotient = divident // divisor
remainder = divident % divisor
print(quotient)
print(quotient)
# Out:
# the dividend (number to divide): 9.2
# Enter the divisor: 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1151/2042415068.py in <cell line: 0>()
#       1 num1 = float(input("the dividend (number to divide): "))
#       2 num2 = float(input("Enter the divisor: "))
# ----> 3 quotient = divident // divisor
#       4 remainder = divident % divisor
#       5 print(quotient)
#
# NameError: name 'divident' is not defined

# %% [markdown]
# 7.	Take three numbers as input and display their average.

# %%
num1 = float(input("enter a first number:"))
num2 = float(input("enter a second number:"))
num3 = float(input("enter a third number:"))
average = (num1 + num2 + num3) / 3
print(average)
# Out:
# enter a first number:7
# enter a second number:8
# enter a third number:7
# 7.333333333333333

# %% [markdown]
# 8.	Write a Python program to calculate the area of a rectangle using the formula: area = length * width.

# %%
length = float(input("Enter a length of rectangle:"))
width = float(input("Enter a width of rectangle"))
area = length * width
print(area)
# Out:
# Enter a length of rectangle:6
# Enter a width of rectangle4
# 24.0

# %% [markdown]
# 9.	Take five numbers as input representing marks obtained and total marks.

# %%
marks_obtained = float(input("Enter total marks obtained: "))
total_marks = float(input("Enter maximum total marks possible: "))

# Calculate percentage
percentage = (marks_obtained / total_marks) * 100

print(f"Percentage: {percentage:.2f}%")
# Out:
# Enter total marks obtained: 56
# Enter maximum total marks possible: 58
# Percentage: 96.55%

# %% [markdown]
# 10.	Write a Python program to swap two numbers entered by the user without using a third variable.

# %%
a = int(input("enter a number"))
b = int(input("enter a number"))
a,b = b, a
print("a={a},b{b}")
# Out:
# enter a number4
# enter a number6
# a={a},b{b}

# %% [markdown]
# 11.	Take a number as input and check whether it is even or odd.

# %%
num = int(input("enter a integer :"))
if num % 2 == 0:
  print("num is even")
else:
  print("num is odd")
# Out:
# enter a integer :6
# num is even

# %% [markdown]
# 12.	Write a Python program to convert temperature from Celsius to Fahrenheit using the formula: F = (C × 9/5) + 32.

# %%
celsius = float(input("Enter temperature in celsius"))
fahrenheit = (celsius * 9/5) +32
print(fahrenheit)
# Out:
# Enter temperature in celsius45
# 113.0

# %% [markdown]
# 13.	Write a Python program to convert temperature from Fahrenheit to Celsius using the formula: C = (F - 32) × 5/9.

# %%
Fahrenheit = float(input("Enter temperature in fahrenheit :"))
celsius = (Fahrenheit - 32) * 5/9
print(celsius)
# Out:
# Enter temperature in fahrenheit :76
# 24.444444444444443

# %% [markdown]
# 14.	Take two numbers as input and find their greatest common divisor (GCD).

# %%
import math
num1 = int(input(" enter a first number"))
num2 = int(input("enter a second number"))
gcd_value = math.gcd (num1, num2)
print(gcd_value)
# Out:
#  enter a first number810
# enter a second number450
# 90

# %% [markdown]
# Question 15: Write a Python program to calculate the simple interest using the formula: SI = (P × R × T) / 100, where P is the principal amount, R is the rate of interest, and T is the time in years.

# %%
p = float(input("Enter principl amount:"))
r = float(input("Enter rate of interst :"))
t = float(input("Enter time in year:"))
si = (p*r*t)/100
print(si)
# Out:
# Enter principl amount:4000
# Enter rate of interst :3
# Enter time in year:2
# 240.0

# %% [markdown]
# Question 16: Write a Python program to check whether a number is positive, negative, or zero.

# %%
num = float(input("enter a number:"))
if num > 0 :
  print("The number is positive")
elif num < 0:
  print("The number is negative")
else:
  print("The number is zero")
# Out:
# enter a number:6
# The number is positive

# %% [markdown]
# Question 17: Write a Python program to find the largest among three numbers entered by the user.

# %%
num1 = int(input("Enter a first number:"))
num2 = int(input("Enter second number:"))
num3 = int(input("Enter second number:"))
if num1 >= num2 and num2 >= num3:
  largest = num1
elif num2 >= num1 and num2 >= num3:
  largest = num2
else:
  largest = num3
print(largest)
# Out:
# Enter a first number:3
# Enter second number:7
# Enter second number:9
# 9

# %% [markdown]
# Question 18: Take a number as input and check whether it is a multiple of 5.

# %%
num = int(input("enter a number:"))
if num % 5 == 0:
  print(num, "is a multiple of 5")
else:
  print(num,"is a not multiple of 5")
# Out:
# enter a number:5
# 5 is a multiple of 5

# %% [markdown]
# Question 19: Write a Python program to calculate the perimeter of a circle using the formula: perimeter = 2 * π * radius.

# %%
import math
radius = float(input("Enter a radius of circle"))
perimeter = 2 * math.pi * radius
print(perimeter)
# Out:
# Enter a radius of circle45
# 282.7433388230814

# %% [markdown]
# Question 20: Write a Python program to check whether a number is divisible by both 3 and 5.

# %%
num = int(input("Enter a number :"))
if num % 3 ==0 and num % 5 == 0:
  print(num,"is divisible by 3 and 5")
else:
  print(num,"is  not divisible by 3 and 5")
# Out:
# Enter a number :15
# 15 is divisible by 3 and 5
